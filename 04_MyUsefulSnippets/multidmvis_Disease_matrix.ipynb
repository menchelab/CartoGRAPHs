# %%
from multidimvis_main import *

# %%
G = nx.read_edgelist('input/ppi_elist.txt',data=False)
# d_ent_sym, d_sym_ent = genent2sym()

d_gene_do = pickle.load( open( "input/d_gene_do.pkl", "rb" ) )
d_do_genes = pickle.load( open( "input/d_do_genes.pkl", "rb" ) )
d_do_names = pickle.load( open( "input/DO_names.pkl", "rb" ) )
d_names_do = {y:x for x,y in d_do_names.items()}

# %% [markdown]
# # DISEASE association Matrix

# %%
all_doids = list(d_do_genes.keys())

subdata = d_gene_do # dict(it.islice(d_gene_do.items(),G.number_of_nodes()))
genes = list(subdata.keys())
genes_doids = subdata.values()

# Get a list of all matches = search for matches of Disease ID list and gene list 
matches = []
for i in genes_doids:
    gene_i = []
    for j in i:
        for idx,value in enumerate(all_doids):
            if j == value:
                gene_i.append(idx)
    matches.append(gene_i)
    
all_match = []
for sub in matches:
    gene_match = [0] * len(all_doids)
    for elem in sub:
        for idx,value in enumerate(gene_match):
            if elem == idx:
                gene_match[idx] = 1
    all_match.append(gene_match)   
    
all_matrix = np.row_stack(all_match)

# %%
df_DIS = pd.DataFrame(all_matrix, columns = all_doids, index = genes, dtype = int)

# %%
df_DIS
# Out:
#         DOID:0001816  DOID:0002116  DOID:0014667  DOID:0050001  DOID:0050002  \
# 389289             0             0             0             0             0
# 4524               0             0             1             0             0
# 4353               0             0             0             0             0
# 27127              0             0             0             0             0
# 5925               0             0             0             0             0
# ...              ...           ...           ...           ...           ...
# 63910              0             0             0             0             0
# 7287               0             0             1             0             0
# 11173              0             0             0             0             0
# 9962               0             0             0             0             0
# 5973               0             0             0             0             0
#
#         DOID:0050003  DOID:0050004  DOID:0050007  DOID:0050009  DOID:0050010  \
# 389289             0             0             0             0             0
# 4524               0             0             0             0             0
# 4353               0             0             0             0             0
# 27127              0             0             0             0             0
# 5925               0             0             0             0             0
# ...              ...           ...           ...           ...           ...
# 63910              0             0             0             0             0
# 7287               0             0             0             0             0
# 11173              0             0             0             0             0
# 9962               0             0             0             0             0
# 5973               0             0             0             0             0
#
#         ...  DOID:9978  DOID:998  DOID:9986  DOID:9987  DOID:9988  DOID:9989  \
# 389289  ...          0         0          0          0          0          0
# 4524    ...          0         0          0          0          0          0
# 4353    ...          0         0          0          0          0          0
# 27127   ...          0         0          0          0          0          0
# 5925    ...          0         0          0          0          0          0
# ...     ...        ...       ...        ...        ...        ...        ...
# 63910   ...          0         0          0          0          0          0
# 7287    ...          0         0          0          0          0          0
# 11173   ...          0         0          0          0          0          0
# 9962    ...          0         0          0          0          0          0
# 5973    ...          0         0          0          0          0          0
#
#         DOID:999  DOID:9993  DOID:9995  DOID:9997
# 389289         0          0          0          0
# 4524           0          0          0          0
# 4353           0          0          0          0
# 27127          0          0          0          0
# 5925           0          0          0          0
# ...          ...        ...        ...        ...
# 63910          0          0          0          0
# 7287           0          0          0          0
# 11173          0          0          0          0
# 9962           0          0          0          0
# 5973           0          0          0          0
#
# [6538 rows x 10897 columns]
