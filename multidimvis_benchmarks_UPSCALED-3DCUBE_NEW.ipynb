# %% [markdown]
# # ===========================
# # Benchmarking - U P S C A L I N G - 3D CUBE
# # ===========================

# %%
from multidimvis_main import *

# %% [markdown]
# # TORUS calculation of network distances - delete when done

# %%
#20k torus

G = nx.grid_2d_graph(182,110,periodic=True)
print(len(G.nodes()))

# %%
#20k cube

G = nx.grid_graph([28,28,28],periodic=False)
print(len(G.nodes()))
# Out:
# 21952

# %%
# RUNNING FROM HERE: 

# torus 20k 
# grid 20k

# %%
# %%time 

all_nodes = list(G.nodes())
l_one = all_nodes[:1000]

print('calculate network distance')
dist_network_one = pairwise_network_distance_parts(G, l_one)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 15min 24s, sys: 118 ms, total: 15min 24s
# Wall time: 15min 24s

# %%
# %%time 

l_two = all_nodes[1001:2000]

print('calculate network distance')
dist_network_two = pairwise_network_distance_parts(G, l_two)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 19min 7s, sys: 109 ms, total: 19min 7s
# Wall time: 20min 2s

# %%
# %%time 

l_thr = all_nodes[2001:3000]

print('calculate network distance')
dist_network_thr = pairwise_network_distance_parts(G, l_thr)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 26min 50s, sys: 166 ms, total: 26min 50s
# Wall time: 27min

# %%
# %%time 

l_fou = all_nodes[3001:4000]

print('calculate network distance')
dist_network_fou = pairwise_network_distance_parts(G, l_fou)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 22min 30s, sys: 201 ms, total: 22min 30s
# Wall time: 22min 30s

# %%
# %%time 

l_fiv = all_nodes[4001:5000]

print('calculate network distance')
dist_network_fiv = pairwise_network_distance_parts(G, l_fiv)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 23min 8s, sys: 243 ms, total: 23min 9s
# Wall time: 23min 9s

# %%
# %%time 

l_si = all_nodes[5001:6000]

print('calculate network distance')
dist_network_si = pairwise_network_distance_parts(G, l_si)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 42min 52s, sys: 321 ms, total: 42min 52s
# Wall time: 43min 15s

# %%
# %%time 

l_sev = all_nodes[6001:7000]

print('calculate network distance')
dist_network_sev = pairwise_network_distance_parts(G, l_sev)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 29min 47s, sys: 241 ms, total: 29min 47s
# Wall time: 29min 54s

# %%
# %%time 

l_ei = all_nodes[7001:8000]

print('calculate network distance')
dist_network_ei = pairwise_network_distance_parts(G, l_ei)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 29min 17s, sys: 280 ms, total: 29min 18s
# Wall time: 29min 18s

# %%
# %%time 

l_ni = all_nodes[8001:9000]

print('calculate network distance')
dist_network_ni = pairwise_network_distance_parts(G, l_ni)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 25min 59s, sys: 217 ms, total: 25min 59s
# Wall time: 25min 59s

# %%
# %%time 

l_te = all_nodes[9001:10000]

print('calculate network distance')
dist_network_te = pairwise_network_distance_parts(G, l_te)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 22min 30s, sys: 250 ms, total: 22min 31s
# Wall time: 22min 31s

# %%
# %%time 

l_el = all_nodes[10001:11000]

print('calculate network distance')
dist_network_el = pairwise_network_distance_parts(G, l_el)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 26min 5s, sys: 251 ms, total: 26min 5s
# Wall time: 26min 6s

# %%
# %%time 

l_twe = all_nodes[11001:12000]

print('calculate network distance')
dist_network_twe = pairwise_network_distance_parts(G, l_twe)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 26min 6s, sys: 242 ms, total: 26min 7s
# Wall time: 26min 7s

# %%
# %%time 

l_thi = all_nodes[12001:13000]

print('calculate network distance')
dist_network_thi = pairwise_network_distance_parts(G, l_thi)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 24min 36s, sys: 217 ms, total: 24min 36s
# Wall time: 24min 36s

# %%
# %%time 

l_fourt = all_nodes[13001:14000]

print('calculate network distance')
dist_network_fourt = pairwise_network_distance_parts(G, l_fourt)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 25min 15s, sys: 333 ms, total: 25min 15s
# Wall time: 25min 15s

# %%
# %%time 

l_fift = all_nodes[14001:15000]

print('calculate network distance')
dist_network_fift = pairwise_network_distance_parts(G, l_fift)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 27min 19s, sys: 211 ms, total: 27min 19s
# Wall time: 27min 19s

# %%
# %%time 

l_sixt = all_nodes[15001:16000]

print('calculate network distance')
dist_network_sixt = pairwise_network_distance_parts(G, l_sixt)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 22min 13s, sys: 158 ms, total: 22min 13s
# Wall time: 22min 13s

# %%
# %%time 

l_sevt = all_nodes[16001:17000]

print('calculate network distance')
dist_network_sevt = pairwise_network_distance_parts(G, l_sevt)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 20min 45s, sys: 192 ms, total: 20min 45s
# Wall time: 20min 45s

# %%
# %%time 

l_eigt = all_nodes[17001:18000]

print('calculate network distance')
dist_network_eigt = pairwise_network_distance_parts(G, l_eigt)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 21min 37s, sys: 139 ms, total: 21min 37s
# Wall time: 21min 37s

# %%
# %%time 

l_nit = all_nodes[18001:19000]

print('calculate network distance')
dist_network_nit = pairwise_network_distance_parts(G, l_nit)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 21min 13s, sys: 134 ms, total: 21min 14s
# Wall time: 21min 14s

# %%
# %%time 

l_twent = all_nodes[19001:20000]

print('calculate network distance')
dist_network_twent = pairwise_network_distance_parts(G, l_twent)
print('distances network done')
# Out:
# calculate network distance
# distances network done
# CPU times: user 17min 13s, sys: 147 ms, total: 17min 13s
# Wall time: 17min 13s

# %%
# %%time 

l_tweone = all_nodes[20001:]

print('calculate network distance')
dist_network_tweone = pairwise_network_distance_parts(G, l_tweone)
print('distances network done')
# Out:
# calculate network distance

# %%
dist_network_next = {#**dist_network_one,
                #**dist_network_two,
                #**dist_network_thr,
                #**dist_network_fou,
                #**dist_network_fiv,
                #**dist_network_si,
                #**dist_network_sev,
                #**dist_network_ei,
                #**dist_network_ni,
                #**dist_network_te,
                #**dist_network_el,
                #**dist_network_twe,
                #**dist_network_thi,
                #**dist_network_fourt,
                #**dist_network_fift,
                #**dist_network_sixt,
                **dist_network_sevt,
                **dist_network_eigt, 
                **dist_network_nit,
                **dist_network_twent,
                **dist_network_tweone
               }

# %%
#a_file = open('dist_network_'+str(len(G.nodes()))+'_torus.pkl', "wb")
a_file = open('dist_network_'+str(len(G.nodes()))+'_cube_part17toend.pkl', "wb")
pickle.dump(dist_network_next, a_file)
a_file.close()

# %%
# 3D CUBE 
organism = 'grid'

feature = 'RWRvis'
r = .9
alpha = 1.0

# parameters (post - testing)
n_neighbors = 8
spread = 1
min_dist = 0.0
metric = 'cosine'
lnr = 1
nep = None

# %% [markdown]
# _________
# # 3D - Cube Grid
# _________

# %%
#########
# 1 0 0 
#########

G = nx.grid_graph([5,5,5],periodic=False)

print('RWR')
start = time.time()
posG_global = globallayout_3D(G,n_neighbors, spread, min_dist, metric)
end = time.time()
m,s = exec_time(start,end)

print('SPRING')
start = time.time()
posG_spring = springlayout_3D(G,itr=2500)
end = time.time()
m,s = exec_time(start,end)

print('\n')

dist_global = pairwise_layout_distance_3D(G,posG_global)
dist_spring = pairwise_layout_distance_3D(G,posG_spring)
dist_network = pairwise_network_distance(G)

r_global = pearson_corrcoef(dist_network, dist_global)
print('RWR corr coef: ',r_global)

r_spring = pearson_corrcoef(dist_network, dist_spring)
print('SPRING corr coef: ',r_spring)
# Out:
# RWR
# Execution Time: 00:00:14
# SPRING
# Execution Time: 00:00:03
#
#
# RWR corr coef:  0.991062872252361
# SPRING corr coef:  0.9923290831675974

# %%
#########
# 5 0 0 
#########

G = nx.grid_graph([8,8,8],periodic=False)

print('RWR')
start = time.time()
posG_global = globallayout_3D(G,n_neighbors, spread, min_dist, metric)
end = time.time()
m,s = exec_time(start,end)

print('SPRING')
start = time.time()
posG_spring = springlayout_3D(G,itr=60)
end = time.time()
m,s = exec_time(start,end)

print('\n')

dist_global = pairwise_layout_distance_3D(G,posG_global)
dist_spring = pairwise_layout_distance_3D(G,posG_spring)
dist_network = pairwise_network_distance(G)

r_global = pearson_corrcoef(dist_network, dist_global)
print('RWR corr coef: ',r_global)

r_spring = pearson_corrcoef(dist_network, dist_spring)
print('SPRING corr coef: ',r_spring)
# Out:
# RWR
# Execution Time: 00:00:03
# prep layout distance
# prep network distance
# prep corr. coeff. data
# calculate corr. coeff.
# RWR corr coef:  0.9987073419798134
#
#
# SPRING
# Execution Time: 00:00:03
# prep layout distance
# prep network distance
# prep corr. coeff. data
# calculate corr. coeff.
# SPRING corr coef:  0.9946175389177597

# %%
#########
# 1 0 0 0 
#########

G = nx.grid_graph([10,10,10],periodic=False)

print('RWR')
start = time.time()
posG_global = globallayout_3D(G,n_neighbors, spread, min_dist, metric)
end = time.time()
m,s = exec_time(start,end)

print('SPRING')
start = time.time()
posG_spring = springlayout_3D(G,itr=125)
end = time.time()
m,s = exec_time(start,end)

print('\n')

dist_global = pairwise_layout_distance_3D(G,posG_global)
dist_spring = pairwise_layout_distance_3D(G,posG_spring)
dist_network = pairwise_network_distance(G)

r_global = pearson_corrcoef(dist_network, dist_global)
print('RWR corr coef: ',r_global)

r_spring = pearson_corrcoef(dist_network, dist_spring)
print('SPRING corr coef: ',r_spring)
# Out:
# RWR
# Execution Time: 00:00:13
# prep layout distance
# prep network distance
# prep corr. coeff. data
# calculate corr. coeff.
# RWR corr coef:  0.9938767421225443
#
#
# SPRING
# Execution Time: 00:00:13
# prep layout distance
# prep network distance
# prep corr. coeff. data
# calculate corr. coeff.
# SPRING corr coef:  0.9864659797520252

# %%
G = nx.grid_graph([10,10,10],periodic=False)

print('Runtime spring for Corr. Coeff. 0.99')

start = time.time()
posG_spring = springlayout_3D(G,itr=400)
end = time.time()
m,s = exec_time(start,end)

dist_spring = pairwise_layout_distance_3D(G,posG_spring)
dist_network = pairwise_network_distance(G)

r_spring = pearson_corrcoef(dist_network, dist_spring)
print('SPRING corr coef: ',r_spring)
# Out:
# Runtime spring for Corr. Coeff. 0.99
# Execution Time: 00:00:44
# prep layout distance
# prep network distance
# prep corr. coeff. data
# calculate corr. coeff.
# SPRING corr coef:  0.9939791128279677

# %%
#########
# 5 0 0 0 
#########

G = nx.grid_graph([18,18,18],periodic=False)

print('RWR')
start = time.time()
posG_global = globallayout_3D(G,n_neighbors, spread, min_dist, metric)
end = time.time()
m,s = exec_time(start,end)

print('SPRING')
start = time.time()
posG_spring = springlayout_3D(G,itr=30)
end = time.time()
m,s = exec_time(start,end)

print('\n')

dist_global = pairwise_layout_distance_3D(G,posG_global)
dist_spring = pairwise_layout_distance_3D(G,posG_spring)
dist_network = pairwise_network_distance(G)

r_global = pearson_corrcoef(dist_network, dist_global)
print('RWR corr coef: ',r_global)

r_spring = pearson_corrcoef(dist_network, dist_spring)
print('SPRING corr coef: ',r_spring)
# Out:
# RWR
# Execution Time: 00:00:57
# prep layout distance
# prep network distance
# prep corr. coeff. data
# calculate corr. coeff.
# RWR corr coef:  0.994673861934273
#
#
# SPRING
# Execution Time: 00:00:49
# prep layout distance
# prep network distance
# prep corr. coeff. data
# calculate corr. coeff.
# SPRING corr coef:  0.5204283449194765

# %%
G = nx.grid_graph([18,18,18],periodic=False)

print('Runtime spring for Corr. Coeff. 0.99')

start = time.time()
posG_spring = springlayout_3D(G,itr=2000)
end = time.time()
m,s = exec_time(start,end)

dist_spring = pairwise_layout_distance_3D(G,posG_spring)
dist_network = pairwise_network_distance(G)

r_spring = pearson_corrcoef(dist_network, dist_spring)
print('SPRING corr coef: ',r_spring)
# Out:
# Runtime spring for Corr. Coeff. 0.99
# Execution Time: 01:00:00
# SPRING corr coef:  0.9961185385037217

# %%
#########
# 1 0 0 0 0 
#########

G = nx.grid_graph([22,22,22],periodic=False)

print('RWR')
start = time.time()
posG_global = globallayout_3D(G,n_neighbors, spread, min_dist, metric)
end = time.time()
m,s = exec_time(start,end)

print('SPRING')
start = time.time()
posG_spring = springlayout_3D(G,itr=20)
end = time.time()
m,s = exec_time(start,end)

print('\n')

dist_global = pairwise_layout_distance_3D(G,posG_global)
dist_spring = pairwise_layout_distance_3D(G,posG_spring)

b_file = open('bench_precalc/dist_network_'+str(len(G.nodes()))+'_cube.pkl', "rb")
dist_network = pickle.load(b_file)
print(len(dist_network))

r_global = pearson_corrcoef(dist_network, dist_global)
print('RWR corr coef: ',r_global)

r_spring = pearson_corrcoef(dist_network, dist_spring)
print('SPRING corr coef: ',r_spring)
# Out:
# RWR
# Execution Time: 00:04:30
# RWR corr coef:  0.9548654230455782

# %%
G = nx.grid_graph([22,22,22],periodic=False)

print('Runtime spring for Corr. Coeff. 0.95')

start = time.time()
posG_spring20k = springlayout_3D(G,itr=5000)
end = time.time()
m,s = exec_time(start,end)

dist_spring20k = pairwise_layout_distance_3D(G,posG_spring20k)

r_spring20k = pearson_corrcoef(dist_network20k, dist_spring20k)
print('SPRING corr coef: ',r_spring20k)

# %%
#########
# 2 0 0 0 0 
#########

G = nx.grid_graph([28,28,28],periodic=False)

print('RWR')
start = time.time()
posG_global = globallayout_3D(G,n_neighbors, spread, min_dist, metric)
end = time.time()
m,s = exec_time(start,end)

dist_global = pairwise_layout_distance_3D(G,posG_global)

r_global = pearson_corrcoef(dist_network, dist_global)
print('RWR corr coef: ',r_global)

print('SPRING')
start = time.time()
posG_spring20k = springlayout_3D(G,itr=50)
end = time.time()
m,s = exec_time(start,end)

dist_spring20k = pairwise_layout_distance_3D(G,posG_spring20k)

b_file20k = open('bench_precalc/dist_network_'+str(len(G.nodes()))+'_cube.pkl', "rb")
dist_network20k = pickle.load(b_file20k)

r_spring20k = pearson_corrcoef(dist_network20k, dist_sprin20k)
print('SPRING corr coef: ',r_spring20k)

# %%
G = nx.grid_graph([28,28,28],periodic=False)

print('Runtime spring for Corr. Coeff. 0.98')

start = time.time()
posG_spring20k = springlayout_3D(G,itr=1000)
end = time.time()
m,s = exec_time(start,end)

dist_spring20k = pairwise_layout_distance_3D(G,posG_spring20k)

r_spring20k = pearson_corrcoef(dist_network20k, dist_spring20k)
print('SPRING corr coef: ',r_spring20k)

# %%
# DELETE CELL WHEN DONE

################
#
# R U N :
# + (28,28,28) UMAP > corr. coeff.
# + (22,22,22) SPRING as long as it needs > for corr.coeff. 0.98
#
################

# 1. 
G = nx.grid_graph([28,28,28],periodic=False)

print('RWR')
start = time.time()
posG_global = globallayout_3D(G,n_neighbors, spread, min_dist, metric)
end = time.time()
m,s = exec_time(start,end)

dist_global = pairwise_layout_distance_3D(G,posG_global)

r_global = pearson_corrcoef(dist_network, dist_global)
print('RWR corr coef: ',r_global)

# %%
#2. 
G = nx.grid_graph([22,22,22],periodic=False)

print('Runtime spring for Corr. Coeff. 0.95')

start = time.time()
posG_spring20k = springlayout_3D(G,itr=5000)
end = time.time()
m,s = exec_time(start,end)

dist_spring20k = pairwise_layout_distance_3D(G,posG_spring20k)

r_spring20k = pearson_corrcoef(dist_network20k, dist_spring20k)
print('SPRING corr coef: ',r_spring20k)

# %% [markdown]
# ## CORR COEF / NETSIZE - saved values for diagram
# + for equal running time

# %%
d_3Dcube_netsize_time = {(5,5,5):1,
                           (8,8,8):3,
                           (10,10,10):13,
                           (18,18,18):57,
                           (22,22,22):260,#4min 19s
                           (28,28,28):991 #16min 30s
                          }

# G L O B A L 
d_3Dcube_netsize_corr_global = {(5,5,5):0.991136860189808,
                           (8,8,8):0.9987073419798134,
                           (10,10,10):0.9938767421225443,
                           (18,18,18):0.9956651448326571,
                           (22,22,22):0.9585264524289082,
                           (28,28,28):0.9864846154726756
                           }

# S P R I N G
d_3Dcube_netsize_corr_spring = {(5 ,5,5):0.9956010674921448,
                           (8,8,8):0.989225957521676,
                           (10,10,10):0.9746359723599757,
                           (18,18,18):0.8703989094585081,
                           (22,22,22):0.7510243876153517,
                           
                           (28,28,28):0.65 # not approved
                           }

# %%
# Network size vs. Correlation Factor 
# with same running time

labelsize = 16 

x_cube = []
for k in d_3Dcube_netsize_time.keys():
    x_cube.append(k[0]**3)
    
x_spring = x_cube
y_spring = list(d_3Dcube_netsize_corr_spring.values())
x_layout = x_cube
y_layout = list(d_3Dcube_netsize_corr_global.values())

fig = plt.figure(figsize=(8,8), dpi=300)

plt.xlabel("Network Size [# Nodes]", fontsize=labelsize)
plt.ylabel("Pearson Corr.Coeff.", fontsize=labelsize)

plt.plot(x_spring,y_spring, '--', c = 'cornflowerblue', alpha = 0.8, linewidth=1.0)
plt.scatter(x_spring,y_spring, c = 'cornflowerblue', s = 30, alpha = 1.0)
plt.plot(x_layout,y_layout, '--', c = 'orange', alpha = 0.8, linewidth=1.0)
plt.scatter(x_layout,y_layout, c = 'orange', s = 30, alpha = 1.0)

plt.grid(True, c='lightgrey', alpha=0.5)
plt.suptitle('3D | Network Size vs. Corr. Factor | '+organism, fontsize=10)
plt.ylim(ymin=0, ymax=1.2)

fig.savefig('output_plots/benchmark/upscaled_3D_CorrNetsize_'+feature+'_'+organism+'.png')

# %% [markdown]
# ## TIME / NETSIZE - saved values for diagram
# + for equal correlation coefficient

# %%
d_3Dcube_netsize_corr = {(5,5,5):0.99,
                           (8,8,8):0.99,
                           (10,10,10):0.99,
                           (18,18,18):0.99,
                           (22,22,22):0.95,
                           (28,28,28):0.98
                           }

# G L O B A L 
d_3Dcube_netsize_time_global = d_3Dcube_netsize_time

# S P R I N G 
d_3Dcube_netsize_time_spring = {(5,5,5):2,
                               (8,8,8):3,
                               (10,10,10):44,
                               (18,18,18):3600,
                                
                               (22,22,22):10000, # not approved
                              
                               (28,28,28):43200 #12h cut off,
                               }

# %%
# Network size vs. Time 
# with same Correlation Factor 

labelsize = 16 

x_cube = []
for k in d_3Dcube_netsize_corr.keys():
    x_cube.append(k[0]**3)
    
x_spring = x_cube
y_spring = [(i/60) for i in d_3Dcube_netsize_time_spring.values()]
x_layout = x_cube
y_layout = [(i/60) for i in d_3Dcube_netsize_time_global.values()]

fig = plt.figure(figsize=(8,8), dpi=300)

plt.xlabel("Network Size [# Nodes]", fontsize=labelsize)
plt.ylabel("Wall Time [min]", fontsize=labelsize)

plt.plot(x_spring,y_spring, '--', c = 'cornflowerblue', alpha = 0.8, linewidth=1.0)
plt.scatter(x_spring,y_spring, c = 'cornflowerblue', s = 30, alpha = 1.0)
plt.plot(x_layout,y_layout, '--', c = 'orange', alpha = 0.8, linewidth=1.0)
plt.scatter(x_layout,y_layout, c = 'orange', s = 30, alpha = 1.0)

# for log scale
#plt.xscale('log')
#plt.yscale('log')

plt.grid(True, c='lightgrey', alpha=0.5)
plt.suptitle('3D | Network Size vs. Wall Time | '+organism, fontsize=10)

fig.savefig('output_plots/benchmark/upscaled_3D_TimeNetsize_'+feature+'_'+organism+'.png')
# loglog : fig.savefig('output_plots/benchmark/upscaled_3D_TimeNetsize_loglog'+feature+'_'+organism+'.png')
# xlog : fig.savefig('output_plots/benchmark/upscaled_3D_TimeNetsize_xlog'+feature+'_'+organism+'.png')
# ylog : fig.savefig('output_plots/benchmark/upscaled_3D_TimeNetsize_ylog'+feature+'_'+organism+'.png')
